# %%
! pip3 install --upgrade  google-cloud-aiplatform \
                          google-cloud-bigquery \
                          google-api-core==2.10
# Out:
# ...
#   Using cached google_cloud_bigquery-3.4.1-py2.py3-none-any.whl (215 kB)
# ...
#   Using cached google_api_core-2.10.0-py3-none-any.whl (115 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 8.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
#   Using cached google_api_core-2.10.2-py3-none-any.whl (115 kB)
#   Using cached google_api_core-2.10.1-py3-none-any.whl (115 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.11.0
#     Uninstalling google-api-core-2.11.0:
#       Successfully uninstalled google-api-core-2.11.0
# ...

# %%
! pip3 freeze | grep google-api-core
# Out:
# google-api-core==2.10.0

# %%
! pip3 install --upgrade  google-cloud-aiplatform

# %%
! pip3 freeze | grep google-api-core
# Out:
# google-api-core==2.10.0

# %%
# !pip3 install --upgrade tensorflow-data-validation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 29.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 48.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pyarrow-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#   Using cached tensorflow_serving_api-2.11.0-py2.py3-none-any.whl (37 kB)
# ...
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.2/120.2 kB 18.8 MB/s eta 0:00:00
# ...
#   Using cached google_api_core-2.10.2-py3-none-any.whl (115 kB)
#   Using cached google_api_core-2.10.1-py3-none-any.whl (115 kB)
#   Using cached google_api_core-2.9.0-py3-none-any.whl (115 kB)
#   Using cached google_api_core-2.8.2-py3-none-any.whl (114 kB)
# WARNING: google-api-core 2.8.2 does not provide the extra 'grpcgcp'
# ...

# %%
! pip3 freeze | grep google-api-core
# Out:
# google-api-core @ file:///home/conda/feedstock_root/build_artifacts/google-api-core-split_1653881570487/work
